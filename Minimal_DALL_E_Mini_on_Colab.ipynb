# %% [markdown]
# <a href="https://colab.research.google.com/github/Prashanthkumarpk/AiImageGenarator/blob/main/Minimal_DALL_E_Mini_on_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install min-dalle -q
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.8/355.8 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
from min_dalle import MinDalle

model = MinDalle(is_mega=True, is_reusable=True)
# Out:
# using device cuda
# downloading tokenizer params
# intializing TextTokenizer
# downloading encoder params
# initializing DalleBartEncoder
# downloading decoder params
# initializing DalleBartDecoder
# downloading detokenizer params
# initializing VQGanDetokenizer

# %%
# %%time

text = "robots using mobile"
seed = 6
grid_size = 2

display(model.generate_image(text, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F49193734C0>
# CPU times: user 27.9 s, sys: 311 ms, total: 28.2 s
# Wall time: 28.3 s
